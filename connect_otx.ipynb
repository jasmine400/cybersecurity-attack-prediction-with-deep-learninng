# %% [markdown]
# <a href="https://colab.research.google.com/github/jasmine400/cybersecurity-attack-prediction-with-deep-learninng/blob/main/connect_otx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install OTXv2

# %%
from OTXv2 import OTXv2, IndicatorTypes

# %%
a=otx.get_all_indicators(  indicator_types=IndicatorTypes.IPv4, limit=10, max_page=1)

# %%
for i in a:
  print(a[i])

# %%
import pandas
from pandas.io.json import json_normalize

# %%
from datetime import datetime, timedelta

# %%
import json

# %%
otx = OTXv2("")

# %%
pulses = otx.getall(limit=10,max_page=1)

# %%
json_normalize(pulses)[0:5]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
#                          id  \
# 0  622f4f68476d6fb93502ddb8
# 1  622f4ce7fe3cba970ea08260
# 2  622f3ca087e68a2746132fc8
# 3  622b5e0b3bbd04a16c3fd971
# 4  622a1df4039af2610815beff
#
#                                                 name  \
# 0  Brazilian trojan impacting Portuguese users an...
# 1  New Wiper Malware Attacking Russia: Deep-dive ...
# 2  Analysis of Attack Activities of Suspected APT...
# 3  Cyberattack on the state authorities of Ukrain...
# 4  Iranian linked conglomerate MuddyWater compris...
#
#                                          description author_name  \
# 0  A new variant of a Brazilian trojan has impact...  AlienVault
# 1  Researchers from Cyble Research Labs have iden...  AlienVault
# ...

# %%
json_normalize(pulses[4]["indicators"])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
#             id                                          indicator  \
# 0   2004956715                                   canarytokens.com
# 1   2197134697  ef385ed64f795e106d17c0a53dfb398f774a555a9e2877...
# 2   2197488365                   72e371542ad6fda96bb3fc3b1ee68d92
# 3   2197488366           3f37ca0db6442743e34768e44450752637930523
# 4   2197505482  6e50e65114131d6529e8a799ff660be0fc5e88ec882a11...
# 5   2197874602                   bb9872bb18840b7e8a887b3be3b621c6
# 6   2197874603           4e68e6daf702c6f8f2a7aed3fb23169f331fd47c
# 7   2198135876                             advanceorthocenter.com
# 8   2213949533                                  lalindustries.com
# 9   2873221843                                     172.245.81.135
# ...

# %%
b=a.iat[7,6]
print(b)
# Out:
# CC=MD ASN=AS43624 Pq Hosting S.r.l.

# %%
indi_info=otx.get_indicator_details_full(IndicatorTypes.IPv4,"185.220.101.6")

# %%
json_object = json.dumps(indi_info, indent = 4)
print(json_object)
# Out:
# {
#     "general": {
#         "whois": "http://whois.domaintools.com/185.220.101.6",
#         "reputation": 0,
#         "indicator": "185.220.101.6",
#         "type": "IPv4",
#         "type_title": "IPv4",
#         "base_indicator": {
#             "id": 212285900,
#             "indicator": "185.220.101.6",
#             "type": "IPv4",
#             "title": "",
#             "description": "",
#             "content": "",
#             "access_type": "public",
#             "access_reason": ""
#         },
#         "pulse_info": {
#             "count": 50,
#             "pulses": [
#                 {
#                     "id": "5a7e3e70c44e7b48947593a7",
#                     "name": "Webscanners 2018-02-09  thru current day",
#                     "description": "Automated detection of webscanners based on 404",
#                     "modified": "2022-03-15T12:35:31.285000",
#                     "created": "2018-02-10T00:36:00.396000",
#                     "tags": [
# ...

# %%
pulses = otx.search_pulses("5a7e3e70c44e7b48947593a7")

# %%
print(pulses)
# Out:
# {'results': [{'id': '5a7e3e70c44e7b48947593a7', 'name': 'Webscanners 2018-02-09  thru current day', 'description': 'Automated detection of webscanners based on 404', 'author_name': 'david3', 'modified': '2022-03-15T12:55:17.694000', 'created': '2018-02-10T00:36:00.396000', 'tags': [], 'references': [], 'public': 1, 'adversary': '', 'targeted_countries': [], 'malware_families': [], 'attack_ids': [], 'industries': [], 'TLP': 'white', 'revision': 5, 'groups': [], 'in_group': False, 'author': {'username': 'david3', 'id': '2807', 'avatar_url': '/otxapi/users/avatar_image/media/avatars/david3/resized/80/fireball-dwf.jpg', 'is_subscribed': False, 'is_following': False}, 'is_subscribing': None}, {'id': '5ba4aab66384d216d2ef5929', 'name': 'Webscanners 2018-02-09 thru current day', 'description': '', 'author_name': 'YaniArdiyanto', 'modified': '2018-09-21T08:24:22.560000', 'created': '2018-09-21T08:24:22.560000', 'tags': [], 'references': [], 'public': 1, 'adversary': '', 'targeted_countries':
# ...

# %%
pulse_details = otx.get_pulse_details("5a7e3e70c44e7b48947593a7")
json_normalize(pulse_details)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                          id                                      name  \
# 0  5a7e3e70c44e7b48947593a7  Webscanners 2018-02-09  thru current day
#
#                                        description author_name  \
# 0  Automated detection of webscanners based on 404      david3
#
#                      modified                     created  \
# 0  2022-03-15T13:35:21.524000  2018-02-10T00:36:00.396000
#
#                                                 tags references  public  \
# 0  [webscanner, bruteforce, web app attack, probi...         []       1
#
#   adversary  ...                                         indicators revision  \
# 0            ...  [{'id': 3332616962, 'indicator': '178.63.95.12...        5
#
#                                               groups in_group is_subscribing  \
# ...

# %%
mtime = (datetime.now() - timedelta(days=1)).isoformat()

# %%
print(type(mtime))
# Out:
# <class 'str'>

# %%
json_normalize(pulses[4]["results"][""])

# %%
a=otx.create_url( url_path='https://otx.alienvault.com/indicator/ip/88.80.186.144')

# %%
print(a)
# Out:
# https://otx.alienvault.com/indicator/ip/88.80.186.144

# %%
 b=otx.walkapi(url='https://otx.alienvault.com/indicator/ip/88.80.186.144',  max_page=1,  method='GET')
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-30-3ed854364566> in <module>()
# ----> 1 b=otx.walkapi(url='https://otx.alienvault.com/indicator/ip/88.80.186.144',  max_page=1,  method='GET')
#
# /usr/local/lib/python3.7/dist-packages/OTXv2.py in walkapi(self, url, iter, max_page, max_items, method, body)
#     383             return self.walkapi_iter(url, max_page=max_page, max_items=max_items, method=method, body=body)
#     384         else:
# --> 385             return list(self.walkapi_iter(url, max_page=max_page, max_items=max_items, method=method, body=body))
#     386
#     387     def getall(self, modified_since=None, author_name=None, limit=50, max_page=None, max_items=None, iter=False):
#
# /usr/local/lib/python3.7/dist-packages/OTXv2.py in walkapi_iter(self, url, max_page, max_items, method, body)
#     364
#     365             if method == 'GET':
# ...
